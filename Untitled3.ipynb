# %%
import numpy as np
import sympy as sp

# %%
g = 1
N = [1, 7, 15]
kl = [0.5, 2]
dg = 0.05
N_up = []
N_down = []
Mu = []
L12 = []
L21 = []
L34 = []
L43 = []
L13 = []
L31 = []
L24 = []
L42 = []
L14 = []
L41 = []
L23 = []
L32 = []

kx = np.linspace(-2, 2, 100)

for i in range(len(N)):
    n_up = N[i]/2
    n_down = N[i]/2
    mu =  (1/2)*(2.05*N[i] - 2*np.sqrt(N[i])/np.pi - 2)
    
    l12 = g*n_up + dg*n_up/2 - (1/(2 * np.pi)*(n_up)/(np.sqrt(n_up+n_down)))
    l21 = g*n_up + dg*n_up/2 - (1/(2 * np.pi)*(n_up)/(np.sqrt(n_up+n_down)))
    l34 = g*n_up + dg*n_up/2 - (1/(2 * np.pi)*(n_up)/(np.sqrt(n_up+n_down)))
    l43 = g*n_up + dg*n_up/2 - (1/(2 * np.pi)*(n_up)/(np.sqrt(n_up+n_down)))                                  
    l13 = g*(np.sqrt(n_up*n_down)) + dg*(np.sqrt(n_up+n_down))/2 - (1/(2 * np.pi)*(np.sqrt(n_up*n_down))/(np.sqrt(n_up+n_down))) - 1
    l31 = g*(np.sqrt(n_up*n_down)) + dg*(np.sqrt(n_up+n_down))/2 - (1/(2 * np.pi)*(np.sqrt(n_up*n_down))/(np.sqrt(n_up+n_down))) - 1
    l24 = g*(np.sqrt(n_up*n_down)) + dg*(np.sqrt(n_up+n_down))/2 - (1/(2 * np.pi)*(np.sqrt(n_up*n_down))/(np.sqrt(n_up+n_down))) - 1
    l42 = g*(np.sqrt(n_up*n_down)) + dg*(np.sqrt(n_up+n_down))/2 - (1/(2 * np.pi)*(np.sqrt(n_up*n_down))/(np.sqrt(n_up+n_down))) - 1
    l14 = g*(np.sqrt(n_up*n_down)) + dg*(np.sqrt(n_up+n_down))/2 - (1/(2 * np.pi)*(np.sqrt(n_up*n_down))/(np.sqrt(n_up+n_down)))
    l41 = g*(np.sqrt(n_up*n_down)) + dg*(np.sqrt(n_up+n_down))/2 - (1/(2 * np.pi)*(np.sqrt(n_up*n_down))/(np.sqrt(n_up+n_down)))                                  
    l23 = g*(np.sqrt(n_up*n_down)) + dg*(np.sqrt(n_up+n_down))/2 - (1/(2 * np.pi)*(np.sqrt(n_up*n_down))/(np.sqrt(n_up+n_down)))
    l32 = g*(np.sqrt(n_up*n_down)) + dg*(np.sqrt(n_up+n_down))/2 - (1/(2 * np.pi)*(np.sqrt(n_up*n_down))/(np.sqrt(n_up+n_down)))
    #l14 = g*(np.sqrt(n_up[i]*n_down[i]) + dg*(np.sqrt(n_up[i]+n_down[i]))/2 - (1/(2 * pi)*(np.sqrt(n_up[i]*n_down[i]))/(np.sqrt(n_up[i]+n_down[i]))                                                                           
                                                                               
    N_up.append(n_up)
    N_down.append(n_down)
    Mu.append(mu)
    L12.append(l12)
    L21.append(l21)                                  
    L34.append(l34)
    L43.append(l43)
    L13.append(l13)
    L31.append(l31)                                  
    L24.append(l24)
    L42.append(l42)                                                                           
    L14.append(l14)
    L41.append(l41)                                  
    L23.append(l23)
    L32.append(l32)   
                                                                               


f1 = []
f2 = []
for j in range(len(kl)):
    for k in range(len(N)):
        for i in range(len(kx)):
            f1_item = kx[i]**2 /2 + kl[j] * kx[i]+2 * N_up[k]+g* N_down[k]+dg/2*(2 * N_up[k]+N_down[k])-(1/(2 * np.pi))*(3 * N_up[k]+ 2*N_down[k])/(np.sqrt(N_up[k]+N_down[k]))- Mu[k]
            f2_item = kx[i]**2 /2 - kl[j] * kx[i]+2 * N_up[k]+g* N_down[k]+dg/2*(2 * N_up[k]+N_down[k])-(1/(2 * np.pi))*(3 * N_up[k]+ 2*N_down[k])/(np.sqrt(N_up[k]+N_down[k]))- Mu[k] 
            f1.append(f1_item)                                                                  
            f2.append(f2_item)
